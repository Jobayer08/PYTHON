# %%
import matplotlib.pyplot as plt 
from sklearn.datasets import make_regression

X,y = make_regression(n_samples=100,
                      n_features=1,
                      random_state=42,
                      noise=20)

plt.scatter(X,y)
plt.xlabel("X-Value")
plt.ylabel("Y-Value")
plt.title("Regression Data")
plt.show()

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

X = np.random.randn(100)  # ১০০টি random মান

sns.boxplot(X, orient="h")
plt.title("Horizontal Box Plot Example")
plt.show()

# %%
import matplotlib.pyplot as plt 
from sklearn.datasets import make_regression

X,y = make_regression(n_samples=100,
                      n_features=1,
                      random_state=42,
                      noise=20)

plt.scatter(X,y)
plt.xlabel("X-Value")
plt.ylabel("Y-Value")
plt.title("Regression Data")
plt.show()

# %%
import seaborn as sns 
sns.boxplot(X,orient="h")
# Out:
# <Axes: >

# %%
Q1 = np.percentile(X,25)
Q3 = np.percentile(X,75)
IQR = (Q3-Q1)
min = Q1 - 1.5*IQR
print(min)
outliers_x = np.random.uniform(min-5,min-2,30).reshape(30,1)
X_outliers = np.concatenate((X,outliers_x),axis=0)
plt.boxplot(X_outliers,orient="h")
plt.show()
# Out:
# -2.1111922542592256
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 8
#       6 outliers_x = np.random.uniform(min-5,min-2,30).reshape(30,1)
#       7 X_outliers = np.concatenate((X,outliers_x),axis=0)
# ----> 8 plt.boxplot(X_outliers,orient="h")
#       9 plt.show()
#
# File F:\Anaconda1\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# ...
